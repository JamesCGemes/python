# %%
import os
os.listdir()
# Out:
# ['annual-enterprise-survey-2020-financial-year-provisional-csv.csv',
#  '.DS_Store',
#  'Untitled.ipynb',
#  'supermarkets.json',
#  'Loading files exercise.ipynb',
#  'supermarkets.csv',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.xlsx',
#  '.ipynb_checkpoints',
#  'supermarkets-commas.txt']

# %%
import pandas

# %%
df01=pandas.read_csv("supermarkets.csv")

# %%
df01
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df01["Continent"]=df01.shape[0]*["North America"]

# %%
df01
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees      Continent
# 0          8  North America
# 1         15  North America
# 2         25  North America
# 3         10  North America
# 4         12  North America
# 5         20  North America

# %%
df01["Continent"]=df01["Country"]+ "," + "North America"

# %%
df01
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees          Continent
# 0          8  USA,North America
# 1         15  USA,North America
# 2         25  USA,North America
# 3         10  USA,North America
# 4         12  USA,North America
# 5         20  USA,North America

# %%
from geopy.geocoders import ArcGIS
nom = ArcGIS()

# %%
nom.geocode("2510 lovetree St, San Antonio, TX78232")
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1345             try:
# -> 1346                 h.request(req.get_method(), req.selector, req.data, headers,
#    1347                           encode_chunked=req.has_header('Transfer-encoding'))
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1252         """Send a complete request to the server."""
# -> 1253         self._send_request(method, url, body, headers, encode_chunked)
#    1254
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1298             body = _encode(body, 'body')
# ...

# %%
nom = ArcGIS()

# %%
nom.geocode("2510 Love Tree St, San Antonio, TX 78232")
# Out:
# Location(2510 Lovetree St, San Antonio, Texas, 78232, (29.575351020123506, -98.45404902401103, 0.0))

# %%
nom.geocode("3995 23rd Street, San Francisco, CA 94114")
# Out:
# Location(3995 23rd St, San Francisco, California, 94114, (37.75292099814533, -122.43170295955227, 0.0))

# %%
df01
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees          Continent
# 0          8  USA,North America
# 1         15  USA,North America
# 2         25  USA,North America
# 3         10  USA,North America
# 4         12  USA,North America
# 5         20  USA,North America

# %%
import pandas
df02=pandas.read_csv("supermarkets.csv")
df02
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df02["Address"]=df02["Address"]+ ", "+["City"]+ ", "+["State"]+ ", "+["Country"]
df02
# Out:
#    ID                                Address           City             State  \
# 0   1     3666 21st St, City, State, Country  San Francisco          CA 94114
# 1   2   735 Dolores St, City, State, Country  San Francisco          CA 94119
# 2   3      332 Hill St, City, State, Country  San Francisco  California 94114
# 3   4     3995 23rd St, City, State, Country  San Francisco          CA 94114
# 4   5  1056 Sanchez St, City, State, Country  San Francisco        California
# 5   6  551 Alvarado St, City, State, Country  San Francisco          CA 94114
#
#   Country         Name  Employees
# 0     USA      Madeira          8
# 1     USA  Bready Shop         15
# 2     USA  Super River         25
# 3     USA   Ben's Shop         10
# 4     USA      Sanchez         12
# 5     USA   Richvalley         20

# %%
df02["Coordinates"]=df02["Address"].apply(nom.geocode)
df02
# Out:
#    ID                                Address           City             State  \
# 0   1     3666 21st St, City, State, Country  San Francisco          CA 94114
# 1   2   735 Dolores St, City, State, Country  San Francisco          CA 94119
# 2   3      332 Hill St, City, State, Country  San Francisco  California 94114
# 3   4     3995 23rd St, City, State, Country  San Francisco          CA 94114
# 4   5  1056 Sanchez St, City, State, Country  San Francisco        California
# 5   6  551 Alvarado St, City, State, Country  San Francisco          CA 94114
#
#   Country         Name  Employees  \
# 0     USA      Madeira          8
# 1     USA  Bready Shop         15
# 2     USA  Super River         25
# 3     USA   Ben's Shop         10
# 4     USA      Sanchez         12
# 5     USA   Richvalley         20
#
#                                          Coordinates
# 0  (3666 21st St NW, Canton, Ohio, 44708, (40.822...
# 1      (ST, (0.2393107930000724, 6.602059996000037))
# ...
